# %% [markdown]
# # Matplotlib Practice
#
# This notebook offers a set of exercises to different tasks with Matplotlib.
#
# It should be noted there may be more than one different way to answer a question or complete an exercise.
#
# Different tasks will be detailed by comments or text.
#
# For further reference and resources, it's advised to check out the [Matplotlib documentation](https://matplotlib.org/3.1.1/contents.html).
#
# If you're stuck, don't forget, you can always search for a function, for example if you want to create a plot with `plt.subplots()`, search for [`plt.subplots()`](https://www.google.com/search?q=plt.subplots()).

# %%
# Import the pyplot module from matplotlib as plt and make sure
import matplotlib.pyplot as plt


# plots appear in the notebook using '%matplotlib inline'
# %matplotlib inline

# %%
# Create a simple plot using plt.plot()

# Sample data
x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]

# Create the plot
plt.plot(x, y)

# Add a title and axis labels
plt.title('Simple Line Plot')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')

# Display the plot
plt.show()

# %%
# Plot a single Python list

# A single list of values
data = [3, 7, 1, 5, 9]

# Plot the list
plt.plot(data)

# Add title and axis labels
plt.title('Plot of a Single Python List')
plt.xlabel('Index')
plt.ylabel('Value')

# Display the plot
plt.show()

# %%
# Create two lists, one called X, one called y, each with 5 numbers in them

X = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# %%
# Plot X & y (the lists you've created)

plt.plot(X, y)

# Add title and labels
plt.title('Plot of X vs y')
plt.xlabel('X')
plt.ylabel('y')

# Display the plot
plt.show()

# %% [markdown]
# There's another way to create plots with Matplotlib, it's known as the object-orientated (OO) method. Let's try it.

# %%
# Create a plot using plt.subplots()

fig, ax = plt.subplots()

# Set title and axis labels
ax.set_title('Plot Using plt.subplots()')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')

# Show the plot
plt.show()

# %%
# Create a plot using plt.subplots() and then add X & y on the axes

# Create a figure and axes using subplots
fig, ax = plt.subplots()

# Plot the data on the axes
ax.plot(X, y)

# Add title and axis labels
ax.set_title('Plot of X vs y using plt.subplots()')
ax.set_xlabel('X')
ax.set_ylabel('y')

# Display the plot
plt.show()

# %% [markdown]
# Now let's try a small matplotlib workflow.

# %%
# Import and get matplotlib ready
import matplotlib.pyplot as plt
# %matplotlib inline

# Prepare data (create two lists of 5 numbers, X & y)

X = [1, 2, 3, 4, 5]
y = [10, 20, 25, 30, 50]


# Setup figure and axes using plt.subplots()
fig, ax = plt.subplots()

# Add data (X, y) to axes
ax.plot(X, y)

# Customize plot by adding a title, xlabel and ylabel
ax.set_title('Plot of X vs y using a small matplotlib workflow')
ax.set_xlabel('X')
ax.set_ylabel('y')

# Save the plot to file using fig.savefig()
fig.savefig('ICP3_plot.png')
plt.show()

# %% [markdown]
# Okay, this is a simple line plot, how about something a little different?
#
# To help us, we'll import NumPy.

# %%
# Import NumPy as np
import numpy as np

# %%
# Create an array of 100 evenly spaced numbers between 0 and 100 using NumPy and save it to variable X
X = np.linspace(0, 100, 100)

# %%
# Create a plot using plt.subplots() and plot X versus X^2 (X squared)
import matplotlib.pyplot as plt
import numpy as np

Y = X ** 2  # X squared

# Create figure and axes
fig, ax = plt.subplots()

# Plot X vs X squared
ax.plot(X, Y)

# Customize the plot
ax.set_title('Plot of X vs X Squared')
ax.set_xlabel('X')
ax.set_ylabel('X Squared')

# Show the plot
plt.show()

# %% [markdown]
# We'll start with scatter plots.

# %%
# Create a scatter plot of X versus the exponential of X (np.exp(X))

Y = np.exp(X)                     # Exponential of X

# Create figure and axes
fig, ax = plt.subplots()

# Create a scatter plot
ax.scatter(X, Y)

# Customize the plot
ax.set_title('Scatter Plot of X vs exp(X)')
ax.set_xlabel('X')
ax.set_ylabel('exp(X)')

# Show the plot
plt.show()

# %%
# Create a scatter plot of X versus np.sin(X)
Y = np.sin(X)

# Create figure and axes
fig, ax = plt.subplots()

# Create a scatter plot
ax.scatter(X, Y)

# Customize the plot
ax.set_title('Scatter Plot of X vs sin(X)')
ax.set_xlabel('X')
ax.set_ylabel('sin(X)')

# Show the plot
plt.show()

# %% [markdown]
# How about we try another type of plot? This time let's look at a bar plot. First we'll make some data.

# %%
# Create a Python dictionary of 3 of your favourite foods with
# The keys of the dictionary should be the food name and the values their price
# Create a dictionary of favorite foods and their prices
favorite_foods = {
    "Chocolate": 5.99,
    "Biryani": 19.50,
    "Ice Cream": 9.95
}

# %%
# Create a bar graph where the x-axis is the keys of the dictionary
# and the y-axis is the values of the dictionary
foods = list(favorite_foods.keys())
prices = list(favorite_foods.values())
fig, ax = plt.subplots()
ax.bar(foods, prices)

# Add a title, xlabel and ylabel to the plot
ax.set_title('Favorite Foods and Their Prices')
ax.set_xlabel('Food')
ax.set_ylabel('Price ($)')
plt.show()

# %%
# Make the same plot as above, except this time make the bars go horizontal
foods = list(favorite_foods.keys())
prices = list(favorite_foods.values())
fig, ax = plt.subplots()
ax.barh(foods, prices)

# Add a title, xlabel and ylabel to the plot
ax.set_title('Favorite Foods and Their Prices')
ax.set_xlabel('Food')
ax.set_ylabel('Price ($)')
plt.show()

# %% [markdown]
# All this food plotting is making me hungry. But we've got a couple of plots to go.
#
# Let's see a histogram.

# %%
# Create a random NumPy array of 1000 normally distributed numbers using NumPy and save it to X

import numpy as np

# Create a random NumPy array of 1000 normally distributed numbers
X = np.random.randn(1000)

# Create a histogram plot of X
fig, ax = plt.subplots()

# Create histogram
ax.hist(X, bins=30, edgecolor='black')

# Customize the plot
ax.set_title('Histogram of Normally Distributed Data')
ax.set_xlabel('Value')
ax.set_ylabel('Frequency')

# Show the plot
plt.show()

# %%
# Create a NumPy array of 1000 random numbers and save it to X

X = np.random.rand(1000)


# Create a histogram plot of X
fig, ax = plt.subplots()

# Create histogram
ax.hist(X, bins=30, edgecolor='black')

# Customize the plot
ax.set_title('Histogram of Uniformly Distributed Random Numbers')
ax.set_xlabel('Value')
ax.set_ylabel('Frequency')

# Show the plot
plt.show()

# %% [markdown]
# Notice how the distributions (spread of data) are different. Why do they differ?
#
#
# Now let's try make some subplots. A subplot is another name for a figure with multiple plots on it.

# %%
# Create an empty subplot with 2 rows and 2 columns (4 subplots total)
fig, axs = plt.subplots(2, 2)

# Add a main title for the whole figure
fig.suptitle('2x2 Subplot Layout')

# Show the empty grid
plt.show()

# %% [markdown]
# Notice how the subplot has multiple figures. Now let's add data to each axes.

# %%
# Create the same plot as above with 2 rows and 2 columns and figsize of (10, 5)
fig, axs = plt.subplots(2, 2, figsize=(10, 5))

# Plot X versus X/2 on the top left axes
x = np.linspace(0, 10, 100)
axs[0, 0].plot(x, x / 2)
axs[0, 0].set_title("X vs X/2")

# Plot a scatter plot of 10 random numbers on each axis on the top right subplot
x_rand = np.random.rand(10)
y_rand = np.random.rand(10)
axs[0, 1].scatter(x_rand, y_rand)
axs[0, 1].set_title("Random Scatter Plot")

# Plot a bar graph of the favourite food keys and values on the bottom left subplot
favorite_foods = {
    "Chocolate": 5.99,
    "Biryani": 19.50,
    "Ice Cream": 9.95
}

foods = list(favorite_foods.keys())
values = list(favorite_foods.values())

axs[1, 0].bar(foods, values)
axs[1, 0].set_title("Favorite Foods")
axs[1, 0].set_xlabel("Food")
axs[1, 0].set_ylabel("Price ($)")



# Plot a histogram of 1000 random normally distributed numbers on the bottom right subplot
data = np.random.randn(1000)
axs[1, 1].hist(data, bins=30)
axs[1, 1].set_title("Histogram of Normal Distribution")

plt.tight_layout()
plt.show()

# %% [markdown]
# Now we've seen how to plot with Matplotlib and data directly.
#
# First we'll need to import pandas and create a DataFrame work with.

# %%
# Import pandas as pd
import pandas as pd

# %%
# Import the '../data/car-sales.csv' into a DataFame called car_sales and view
import pandas as pd

car_sales = pd.read_csv('car-sales (1).csv')
pd.set_option('display.max_rows', None)

# Display the full DataFrame
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Try to plot the 'Price' column using the plot() function

import pandas as pd
import matplotlib.pyplot as plt

# Load the data
car_sales = pd.read_csv('car-sales (1).csv')

# Step 1: Convert 'Price' column to numeric
car_sales['Price'] = car_sales['Price'].replace('[\$,]', '', regex=True).astype(float)

# Step 2: Create 'Total Sales' column (cumulative sum of prices)
car_sales['Total Sales'] = car_sales['Price'].cumsum()

# Step 3: Create a 'Sale Date' column with one date per row
car_sales['Sale Date'] = pd.date_range(start='2023-01-01', periods=len(car_sales), freq='D')

# Step 4: Plot the Price column
car_sales['Price'].plot()
plt.title('Car Prices Over Time (by Index)')
plt.xlabel('Index')
plt.ylabel('Price ($)')
plt.show()

# %% [markdown]
# Why doesn't it work?
#
# Hint: It's not numeric data.
#
# In the process of turning it to numeric data, let's create another column which adds the total amount of sales and another one which shows what date the car was sold.
#
# Hint: To add a column up cumulatively, look up the cumsum() function. And to create a column of dates, look up the date_range() function.

# %%
# Remove the symbols, the final two numbers from the 'Price' column and convert it to numbers
import pandas as pd

# Load the data
car_sales = pd.read_csv('car-sales (1).csv')

# Step 1: Remove symbols like '$' and ',' using regex
car_sales['Price'] = car_sales['Price'].replace('[\$,]', '', regex=True)

# Step 2: Remove the last two digits from the price string
car_sales['Price'] = car_sales['Price'].str[:-2]

# Step 3: Convert to numeric
car_sales['Price'] = car_sales['Price'].astype(float)

# View the cleaned column
print(car_sales['Price'].head())
# Out:
# 0     4000.0
# 1     5000.0
# 2     7000.0
# 3    22000.0
# 4     3500.0
# Name: Price, dtype: float64

# %%
# Add a column called 'Total Sales' to car_sales which cumulatively adds the 'Price' column
import pandas as pd
from datetime import datetime
car_sales['Total Sales'] = car_sales['Price'].cumsum()

# Add a column called 'Sale Date' which lists a series of successive dates starting from today (your today)
today = pd.to_datetime(datetime.today().date())
car_sales['Sale Date'] = pd.date_range(start=today, periods=len(car_sales), freq='D')

# View the car_sales DataFrame
print(car_sales)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Total Sales  Sale Date
# 0  Toyota  White         150043      4   4000.0       4000.0 2025-07-15
# 1   Honda    Red          87899      4   5000.0       9000.0 2025-07-16
# 2  Toyota   Blue          32549      3   7000.0      16000.0 2025-07-17
# 3     BMW  Black          11179      5  22000.0      38000.0 2025-07-18
# 4  Nissan  White         213095      4   3500.0      41500.0 2025-07-19
# 5  Toyota  Green          99213      4   4500.0      46000.0 2025-07-20
# 6   Honda   Blue          45698      4   7500.0      53500.0 2025-07-21
# 7   Honda   Blue          54738      4   7000.0      60500.0 2025-07-22
# 8  Toyota  White          60000      4   6250.0      66750.0 2025-07-23
# 9  Nissan  White          31600      4   9700.0      76450.0 2025-07-24

# %% [markdown]
# Now we've got a numeric column (`Total Sales`) and a dates column (`Sale Date`), let's visualize them.

# %%
# Use the plot() function to plot the 'Sale Date' column versus the 'Total Sales' column
import matplotlib.pyplot as plt

# Plot 'Sale Date' vs 'Total Sales'
car_sales.plot(x='Sale Date', y='Total Sales', kind='line')

# Add labels and title
plt.title("Total Sales Over Time")
plt.xlabel("Sale Date")
plt.ylabel("Total Sales ($)")
plt.xticks(rotation=45)  # Rotate date labels for readability
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Convert the 'Price' column to the integers
car_sales['Price'] = car_sales['Price'].astype(int)


# Create a scatter plot of the 'Odometer (KM)' and 'Price' column using the plot() function
car_sales.plot(x='Odometer (KM)', y='Price', kind='scatter')

# Add labels and title
plt.title('Price vs. Odometer Reading')
plt.xlabel('Odometer (KM)')
plt.ylabel('Price ($)')
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Create a NumPy array of random numbers of size (10, 4) and save it to X

import numpy as np

X = np.random.rand(10, 4)

# Turn the NumPy array X into a DataFrame with columns called ['a', 'b', 'c', 'd']
df = pd.DataFrame(X, columns=['a', 'b', 'c', 'd'])

# Create a bar graph of the DataFrame
df.plot(kind='bar')

# Add labels and title
plt.title("Bar Graph of DataFrame")
plt.xlabel("Index")
plt.ylabel("Values")
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Create a bar graph of the 'Make' and 'Odometer (KM)' columns in the car_sales DataFrame

import matplotlib.pyplot as plt

# Group by 'Make' and calculate the average 'Odometer (KM)'
make_odometer_avg = car_sales.groupby('Make')['Odometer (KM)'].mean()

# Plot as a bar graph
make_odometer_avg.plot(kind='bar')

# Add labels and title
plt.title("Average Odometer Reading by Car Make")
plt.xlabel("Car Make")
plt.ylabel("Odometer (KM)")
plt.xticks(rotation=45)
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Create a histogram of the 'Odometer (KM)' column
import matplotlib.pyplot as plt

# Create a histogram of 'Odometer (KM)'
car_sales['Odometer (KM)'].plot(kind='hist', bins=20)

# Add labels and title
plt.title("Distribution of Odometer Readings")
plt.xlabel("Odometer (KM)")
plt.ylabel("Frequency")
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Create a histogram of the 'Price' column with 20 bins
import matplotlib.pyplot as plt

# Create histogram of 'Price' with 20 bins
car_sales['Price'].plot(kind='hist', bins=20)

# Add labels and title
plt.title("Distribution of Car Prices")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# Now we've seen a few examples of plotting directly from DataFrames using the `car_sales` dataset.
#
# Let's try using a different dataset.

# %%
# Import "../data/heart-disease.csv" and save it to the variable "heart_disease"
import pandas as pd

# Load the uploaded CSV into a DataFrame
heart_disease = pd.read_csv('heart-disease (1).csv')

# %%
# View the first 10 rows of the heart_disease DataFrame
heart_disease.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1
# 7   0     3       1
# 8   0     3       1
# 9   0     2       1

# %%
# Create a histogram of the "age" column with 50 bins
import matplotlib.pyplot as plt

# Create histogram of 'age' with 50 bins
heart_disease['age'].plot(kind='hist', bins=50)

# Add labels and title
plt.title("Distribution of Age")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Call plot.hist() on the heart_disease DataFrame and toggle the
# "subplots" parameter to True
import matplotlib.pyplot as plt

# Plot histograms for all numeric columns with enough space
heart_disease.plot.hist(
    subplots=True,
    figsize=(15, 12),
    bins=30,
    layout=(5, 3),   # 5 rows x 3 columns = 15 plots
    sharex=False
)

plt.tight_layout()
plt.show()

# %% [markdown]
# That plot looks pretty squished. Let's change the figsize.

# %%
# Call the same line of code from above except change the "figsize" parameter
# to be (10, 30)
import matplotlib.pyplot as plt

# Plot histograms for all numeric columns with enough space
heart_disease.plot.hist(
    subplots=True,
    figsize=(10, 30),
    bins=30,
    layout=(5, 3),   # 5 rows x 3 columns = 15 plots
    sharex=False
)

plt.tight_layout()
plt.show()

# %% [markdown]
# Now let's try comparing two variables versus the target variable.
#
# More specifially we'll see how age and cholesterol combined effect the target in **patients over 50 years old**.
#
# For this next challenge, we're going to be replicating the plot1:

# %%
# Replicate the above plot in whichever way you see fit

# Note: The method below is only one way of doing it, yours might be
# slightly different

# Create DataFrame with patients over 50 years old
over_50 = heart_disease[heart_disease['age'] > 50]

# Create the plot
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the data
ax.scatter(over_50['age'], over_50['chol'])

# Customize the plot
ax.set_title('Cholesterol Levels of Patients Over 50')
ax.set_xlabel('Age')
ax.set_ylabel('Cholesterol')
ax.grid(True)

# Add a meanline
mean_chol = over_50['chol'].mean()
ax.axhline(mean_chol, color='red', linestyle='--', label=f'Mean Cholesterol ({mean_chol:.1f})')
ax.legend()

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Now you've created a plot of two different variables, let's change the style.

# %%
# Check what styles are available under plt
import matplotlib.pyplot as plt

# List all available styles
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
# Change the style to use "seaborn-whitegrid"
import matplotlib.pyplot as plt

plt.style.use('seaborn-v0_8-whitegrid')

# %% [markdown]
# Now the style has been changed, we'll replot the same figure from above and see what it looks like.
#
# If you've changed the style correctly, it should look like plot2

# %%
# Reproduce the same figure as above with the "seaborn-whitegrid" style

# Create the plot
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the data
ax.scatter(over_50['age'], over_50['chol'])

# Customize the plot
ax.set_title('Cholesterol Levels of Patients Over 50')
ax.set_xlabel('Age')
ax.set_ylabel('Cholesterol')
ax.grid(True)

# Add a meanline
# Add a meanline
mean_chol = over_50['chol'].mean()
ax.axhline(mean_chol, color='red', linestyle='--', label=f'Mean Cholesterol ({mean_chol:.1f})')
ax.legend()

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Wonderful, you've changed the style of the plots and the figure is looking different but the dots aren't a very good colour.
#
# Let's change the `cmap` parameter of `scatter()` as well as the `color` parameter of `axhline()` to fix it.
#
# Completing this step correctly should result in a figure which looks like plot3

# %%
# Replot the same figure as above except change the "cmap" parameter
# of scatter() to "winter"
# Also change the "color" parameter of axhline() to "red"

# Create the plot
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the data
scatter = ax.scatter(
    over_50['age'],
    over_50['chol'],
    c=over_50['chol'],
    cmap='winter',
    edgecolor='black'  # Note: may be ignored with unfilled marker types
)

# Customize the plot
ax.set_title('Cholesterol Levels of Patients Over 50')
ax.set_xlabel('Age')
ax.set_ylabel('Cholesterol')
ax.grid(True)

# Add a meanline
mean_chol = over_50['chol'].mean()
ax.axhline(mean_chol, color='red', linestyle='--', label=f'Mean Cholesterol ({mean_chol:.1f})')

# Add legend and colorbar
ax.legend()
plt.colorbar(scatter, ax=ax, label='Cholesterol')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Beautiful! Now our figure has an upgraded color scheme let's save it to file.

# %%
# Save the current figure using savefig(), the file name can be anything you want
fig.savefig(r'C:\Users\admin\Downloads\Code_Help\Code_Help\ICP3_PIC.png')

# %%
# Reset the figure by calling plt.subplots()
import matplotlib.pyplot as plt

# Reset the figure by creating a new one
fig, ax = plt.subplots()
